# %% [markdown]
# <a href="https://colab.research.google.com/github/Sandeep4118/colab-project/blob/main/Data_Visualization_Seaborn.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Here numerical value called quantative variable and categorical value called qualatative varibale.

# %%
# Distribution plot for contigous variable like numerical value.

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = sns.load_dataset('tips')
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
df['size'].unique()
# Out:
# array([2, 3, 4, 1, 6, 5])

# %%
# 1) histplot type of Distribution plot.
# histogram which is used for showcasing of data.
# if the bins=1 then all the value goes into only one bin.
# and if the bins=3 then all the value goes into 3 bins according their value.
sns.histplot(df['total_bill'],bins=20,kde=True)
# Out:
# <Axes: xlabel='total_bill', ylabel='Count'>

# %%
plt.subplot(1,2,1)
sns.histplot(df['total_bill'],bins=20,kde=True)
plt.subplot(1,2,2)
sns.histplot(df['tip'],bins=20,kde=True)
# Out:
# <Axes: xlabel='tip', ylabel='Count'>

# %%
# 2) jointplot

# %%
sns.jointplot(data=df,x='total_bill',y='tip',kind='scatter')

# %%
sns.jointplot(data=df,x='total_bill',y='tip',kind='hist')

# %%
sns.jointplot(data=df,x='total_bill',y='tip',kind='kde')

# %%
sns.jointplot(data=df,x='total_bill',y='tip',kind='hex')

# %%
sns.jointplot(data=df,x='total_bill',y='tip',kind='reg')

# %%
# 3)Pair Plot

# %%
sns.pairplot(df,hue='size',palette='rainbow')

# %%
# rugplot

# %%
sns.rugplot(df)
# Out:
# <Axes: >

# %%
#  Categorical Data Plots for categorical value.

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = sns.load_dataset('tips')

# %%
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
# Types of Categorical Data Plots
# boxplot
# vinlinplot
# stripplot
# swarmplot
# barplot
# countplot

# %%
# countplot : if we want to find the no. of males and female and which one smoke more. then we use countplot.

# %%
sns.countplot(x = df['sex'],hue = df['smoker'])
# Out:
# <Axes: xlabel='sex', ylabel='count'>

# %%
# barplot: Here on y-axis all numerical values show's and on x-axis all categrocial value's show

# %%
sns.barplot(x=df['sex'],y=df['tip'])
# Out:
# <Axes: xlabel='sex', ylabel='tip'>

# %%
# You can change the estimator object to your own function, that converts a vector to a scalar
# Mean (default) : np.mean
# Meadian: np.median
# Sum : np.sum
# Count : len(to count the number of observations)
# Standard Deviation : np.std
# Minimum : np.min
# Maximum : np.max

# %%
import numpy as np
sns.barplot(x=df['sex'],y=df['tip'],estimator=np.sum)
# It gives the total estimated tip of male and female seperately.
# Out:
# <Axes: xlabel='sex', ylabel='tip'>

# %%
sns.barplot(x=df['sex'],y=df['total_bill'],estimator=np.sum)
# Out:
# <Axes: xlabel='sex', ylabel='total_bill'>

# %%
# boxplot : Boxplot is a graph that shows the distribution of data and helps identify outliers.
# boxplot are builts using 5 number summary in Statics.

# %%
sns.boxplot(x=df['tip'],y=df['day'],data=df,palette='rainbow')
# Out:
# /tmp/ipykernel_6475/1505517843.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x=df['tip'],y=df['day'],data=df,palette='rainbow')
# <Axes: xlabel='tip', ylabel='day'>

# %%
# violinplot : Violin plot is a graph that shows the distribution of data along with its shape and density.

# %%
# Boxplot/Violinplot = numerical data ko different categories me compare karne ke liye.

# %%
sns.violinplot(x=df['day'], y=df['total_bill'],data=df)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
# Stripplot : Strip plot shows individual data points as dots for each category.
# Striplot : dots thode overlap ho sakte hain.
# Swarmplot : dots perfectly arranged (no overlap).
# Swarmplot : Swarm plot also shows individual points but arranged neatly without overlap.
# Stripplot = scattered dots
# Swarmplot = well-organized dots

# Categorical vs Numerical data ke individual points dekhne ke liye.

# %%
sns.stripplot(x=df['day'], y=df['total_bill'],data=df)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.swarmplot(x=df['day'], y=df['total_bill'],data=df)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
# combining violinplot and swarmplot together.
sns.violinplot(x='tip',y='day',data=df,palette='rainbow')
sns.swarmplot(x='tip',y='day',data=df,palette='bright')
# Out:
# /tmp/ipykernel_6475/517787623.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(x='tip',y='day',data=df,palette='rainbow')
# /tmp/ipykernel_6475/517787623.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.swarmplot(x='tip',y='day',data=df,palette='bright')
# /usr/local/lib/python3.12/dist-packages/seaborn/categorical.py:3399: UserWarning: 9.7% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.12/dist-packages/seaborn/categorical.py:3399: UserWarning: 10.3% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
# ...

# %%
# Matrixplot

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Heat Map

# %%
flights = sns.load_dataset('flights')
flights
# Out:
#      year month  passengers
# 0    1949   Jan         112
# 1    1949   Feb         118
# 2    1949   Mar         132
# 3    1949   Apr         129
# 4    1949   May         121
# ..    ...   ...         ...
# 139  1960   Aug         606
# 140  1960   Sep         508
# 141  1960   Oct         461
# 142  1960   Nov         390
# 143  1960   Dec         432
#
# [144 rows x 3 columns]

# %%
tips = sns.load_dataset('tips')
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
# Correlation is used to check how two variables are related to each other.
# It helps us understand if one value increases or decreases with another.
# Correlation is lied between -1 to +1 and if the value is 0 then this variable is not for the prediction.

# %%
# Selecting only numeric value.
tipscorr = tips[['total_bill','tip','size']]

# %%
tipscorr
# Out:
#      total_bill   tip  size
# 0         16.99  1.01     2
# 1         10.34  1.66     3
# 2         21.01  3.50     3
# 3         23.68  3.31     2
# 4         24.59  3.61     4
# ..          ...   ...   ...
# 239       29.03  5.92     3
# 240       27.18  2.00     2
# 241       22.67  2.00     2
# 242       17.82  1.75     2
# 243       18.78  3.00     2
#
# [244 rows x 3 columns]

# %%
tipscorr.corr()
# Out:
#             total_bill       tip      size
# total_bill    1.000000  0.675734  0.598315
# tip           0.675734  1.000000  0.489299
# size          0.598315  0.489299  1.000000

# %%
sns.heatmap(tipscorr.corr(),annot=True)
# Out:
# <Axes: >

# %%
# Cluster map

# %%
sns.clustermap(tipscorr.corr(),annot=True)

# %%
# Pivot Table with Heat Map

# %%
pvtflight = flights.pivot_table(values='passengers',index='month',columns='year')
pvtflight
# Out:
# /tmp/ipykernel_6475/3963259204.py:1: FutureWarning: The default value of observed=False is deprecated and will change to observed=True in a future version of pandas. Specify observed=False to silence this warning and retain the current behavior
#   pvtflight = flights.pivot_table(values='passengers',index='month',columns='year')
# year    1949   1950   1951   1952   1953   1954   1955   1956   1957   1958  \
# month
# Jan    112.0  115.0  145.0  171.0  196.0  204.0  242.0  284.0  315.0  340.0
# Feb    118.0  126.0  150.0  180.0  196.0  188.0  233.0  277.0  301.0  318.0
# Mar    132.0  141.0  178.0  193.0  236.0  235.0  267.0  317.0  356.0  362.0
# Apr    129.0  135.0  163.0  181.0  235.0  227.0  269.0  313.0  348.0  348.0
# May    121.0  125.0  172.0  183.0  229.0  234.0  270.0  318.0  355.0  363.0
# Jun    135.0  149.0  178.0  218.0  243.0  264.0  315.0  374.0  422.0  435.0
# Jul    148.0  170.0  199.0  230.0  264.0  302.0  364.0  413.0  465.0  491.0
# ...

# %%
sns.heatmap(pvtflight)
# Out:
# <Axes: xlabel='year', ylabel='month'>

# %%
# Regression plot

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# To used Regression we can use lmplot()

# %%
tips = sns.load_dataset('tips')

# %%
# here on the x-axis we need to give input and y-axiz we the predict output

# %%
sns.lmplot(x='total_bill',y='tip',data=tips,hue='sex',markers=['o','v'])

# %%
# !pip install plotly

# %%
pip install cufflinks
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 25.3 MB/s eta 0:00:00
# ...

# %%
# plotly is a python library which is used to design graphs, especially interactive graphs. It can plot various graphs and charts like histogram, barplot, boxplot, spreadplot and many more. It is mainly used in data analysis as well as financial analysis. plotly is an interactive visualization library.

# %%
# cufflinks connects plotly with pandas to create graphs and charts of dataframes directly.

# %%
# !pip install cufflinks plotly --quiet

import seaborn as sns
import cufflinks as cf
from plotly.offline import iplot

cf.go_offline()

tips = sns.load_dataset('tips')

tips.groupby('day')['tip'].mean().iplot(
    kind='bar',
    colors=['orange']
)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.35.2.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# /tmp/ipykernel_6475/3435314557.py:11: FutureWarning:
#
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
# ---------------------------------------------------------------------------
# ...
